# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import re

# %%
train = pd.read_csv(r"C:\Users\raven\Downloads\sf-crime\train.csv\train.csv")
test  = pd.read_csv(r"C:\Users\raven\Downloads\sf-crime\test.csv\test.csv")

# %%
train.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y
# 0 -122.425892  37.774599
# 1 -122.425892  37.774599
# 2 -122.424363  37.800414
# 3 -122.426995  37.800873
# 4 -122.438738  37.771541

# %%
train1 = train.query("Category=='NON-CRIMINAL'&PdDistrict=='RICHMOND'")
train1
# Out:
#                       Dates      Category  \
# 245     2015-05-13 12:00:00  NON-CRIMINAL
# 267     2015-05-13 10:00:00  NON-CRIMINAL
# 306     2015-05-13 07:00:00  NON-CRIMINAL
# 489     2015-05-12 17:00:00  NON-CRIMINAL
# 497     2015-05-12 16:45:00  NON-CRIMINAL
# ...                     ...           ...
# 877590  2003-01-07 07:20:00  NON-CRIMINAL
# 877591  2003-01-07 07:20:00  NON-CRIMINAL
# 877663  2003-01-06 23:00:00  NON-CRIMINAL
# 877836  2003-01-06 15:21:00  NON-CRIMINAL
# 877880  2003-01-06 13:00:00  NON-CRIMINAL
#
#                                     Descript  DayOfWeek PdDistrict  \
# 245                               AIDED CASE  Wednesday   RICHMOND
# 267                           FOUND PROPERTY  Wednesday   RICHMOND
# 306                           FOUND PROPERTY  Wednesday   RICHMOND
# 489     AIDED CASE -PROPERTY FOR DESTRUCTION    Tuesday   RICHMOND
# 497                            LOST PROPERTY    Tuesday   RICHMOND
# ...                                      ...        ...        ...
# 877590          AIDED CASE, MENTAL DISTURBED    Tuesday   RICHMOND
# 877591                            AIDED CASE    Tuesday   RICHMOND
# 877663                         LOST PROPERTY     Monday   RICHMOND
# 877836           DEATH REPORT, CAUSE UNKNOWN     Monday   RICHMOND
# 877880                         LOST PROPERTY     Monday   RICHMOND
#
#                Resolution                          Address           X  \
# 245             UNFOUNDED          100 Block of FUNSTON AV -122.472048
# 267                  NONE             25TH AV / CLEMENT ST -122.484873
# 306                  NONE              400 Block of 4TH AV -122.462139
# 489                  NONE             400 Block of 17TH AV -122.476165
# 497                  NONE               GEARY BL / 20TH AV -122.479384
# ...                   ...                              ...         ...
# 877590  PSYCHOPATHIC CASE  CALIFORNIA ST / COMMONWEALTH AV -122.455866
# 877591  PSYCHOPATHIC CASE  CALIFORNIA ST / COMMONWEALTH AV -122.455866
# 877663               NONE               25TH AV / GEARY BL -122.484732
# 877836               NONE              700 Block of 8TH AV -122.466019
# 877880               NONE           3200 Block of GEARY BL -122.453658
#
#                 Y
# 245     37.785390
# 267     37.782023
# 306     37.780127
# 489     37.779493
# 497     37.780333
# ...           ...
# 877590  37.786104
# 877591  37.786104
# 877663  37.780092
# 877836  37.774314
# 877880  37.781533
#
# [5744 rows x 9 columns]

# %%
train2 = train.query("Category=='NON-CRIMINAL'&PdDistrict=='RICHMOND'&Resolution!='NONE'")
train2
# Out:
#                       Dates      Category                      Descript  \
# 245     2015-05-13 12:00:00  NON-CRIMINAL                    AIDED CASE
# 2402    2015-04-30 18:00:00  NON-CRIMINAL                FOUND PROPERTY
# 3728    2015-04-27 12:00:00  NON-CRIMINAL               COURTESY REPORT
# 3739    2015-04-27 12:00:00  NON-CRIMINAL                  CASE CLOSURE
# 3915    2015-04-19 21:51:00  NON-CRIMINAL  AIDED CASE, MENTAL DISTURBED
# ...                     ...           ...                           ...
# 871853  2003-02-03 21:30:00  NON-CRIMINAL  AIDED CASE, MENTAL DISTURBED
# 872176  2003-02-03 05:02:00  NON-CRIMINAL                   FIRE REPORT
# 874430  2003-01-21 22:14:00  NON-CRIMINAL  AIDED CASE, MENTAL DISTURBED
# 877590  2003-01-07 07:20:00  NON-CRIMINAL  AIDED CASE, MENTAL DISTURBED
# 877591  2003-01-07 07:20:00  NON-CRIMINAL                    AIDED CASE
#
#         DayOfWeek PdDistrict           Resolution  \
# 245     Wednesday   RICHMOND            UNFOUNDED
# 2402     Thursday   RICHMOND            UNFOUNDED
# 3728       Monday   RICHMOND            UNFOUNDED
# 3739       Monday   RICHMOND            UNFOUNDED
# 3915       Sunday   RICHMOND            UNFOUNDED
# ...           ...        ...                  ...
# 871853     Monday   RICHMOND    PSYCHOPATHIC CASE
# 872176     Monday   RICHMOND       JUVENILE CITED
# 874430    Tuesday   RICHMOND  JUVENILE ADMONISHED
# 877590    Tuesday   RICHMOND    PSYCHOPATHIC CASE
# 877591    Tuesday   RICHMOND    PSYCHOPATHIC CASE
#
#                                 Address           X          Y
# 245             100 Block of FUNSTON AV -122.472048  37.785390
# 2402        3600 Block of SACRAMENTO ST -122.452796  37.787500
# 3728       500 Block of JOHNFKENNEDY DR -122.466205  37.772541
# 3739       500 Block of JOHNFKENNEDY DR -122.466205  37.772541
# 3915             5200 Block of GEARY BL -122.475647  37.780631
# ...                                 ...         ...        ...
# 871853         700 Block of CABRILLO ST -122.466559  37.775192
# 872176              CLAY ST / CHERRY ST -122.457061  37.787809
# 874430          4700 Block of BALBOA ST -122.509645  37.775207
# 877590  CALIFORNIA ST / COMMONWEALTH AV -122.455866  37.786104
# 877591  CALIFORNIA ST / COMMONWEALTH AV -122.455866  37.786104
#
# [1207 rows x 9 columns]
