# %%
import lightgbm as lgb
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# ボストン市の住宅価格データを読み込み
boston = load_boston()
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.2, random_state=42)

# LightGBMの学習器を作成
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# ハイパーパラメータの設定
params = {
    'objective': 'regression',
    'metric': 'rmse',
    'num_leaves': 31,
    'learning_rate': 0.1,
}

# モデルの学習
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=100,
                valid_sets=lgb_eval,
                early_stopping_rounds=10)

# テストデータによる予測
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)

# モデルの評価
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print('RMSE: {:.3f}'.format(rmse))
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001429 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1030
# [LightGBM] [Info] Number of data points in the train set: 404, number of used features: 13
# [LightGBM] [Info] Start training from score 22.796535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's rmse: 8.0308
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's rmse: 7.46399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's rmse: 6.93679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's rmse: 6.5007
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's rmse: 6.08904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's rmse: 5.73428
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's rmse: 5.45342
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's rmse: 5.19457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's rmse: 4.99355
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's rmse: 4.78437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's rmse: 4.61764
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's rmse: 4.46405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's rmse: 4.29502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's rmse: 4.17759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's rmse: 4.06042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's rmse: 3.9478
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's rmse: 3.88997
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's rmse: 3.80554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's rmse: 3.73688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's rmse: 3.69405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's rmse: 3.62268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's rmse: 3.58949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's rmse: 3.56165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's rmse: 3.50935
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's rmse: 3.49641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's rmse: 3.46308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's rmse: 3.42235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's rmse: 3.39351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's rmse: 3.38182
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's rmse: 3.35291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's rmse: 3.32167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's rmse: 3.30062
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's rmse: 3.27536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's rmse: 3.25926
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's rmse: 3.23739
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's rmse: 3.21188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's rmse: 3.20293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's rmse: 3.20975
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's rmse: 3.18908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's rmse: 3.17779
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's rmse: 3.16779
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's rmse: 3.14513
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's rmse: 3.1201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's rmse: 3.12565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's rmse: 3.12416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's rmse: 3.13229
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's rmse: 3.13396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's rmse: 3.13782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's rmse: 3.12619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's rmse: 3.12199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's rmse: 3.12309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's rmse: 3.13127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's rmse: 3.12758
# Early stopping, best iteration is:
# [43]	valid_0's rmse: 3.1201
# RMSE: 3.120
# c:\Users\raven\anaconda3\anaconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)
